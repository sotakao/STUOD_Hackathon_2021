# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
# !wget ftp://ftp.ifremer.fr/ifremer/cersat/projects/stuod/hackathon/elnino//cci_sst_1981_2018.nc.gz
    
# !gunzip -d cci_sst_1981_2018.nc
# Out:
# --2021-03-22 20:40:18--  ftp://ftp.ifremer.fr/ifremer/cersat/projects/stuod/hackathon/elnino//cci_sst_1981_2018.nc.gz
#            => ‘cci_sst_1981_2018.nc.gz’
# Resolving ftp.ifremer.fr (ftp.ifremer.fr)... 134.246.142.21
# Connecting to ftp.ifremer.fr (ftp.ifremer.fr)|134.246.142.21|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /ifremer/cersat/projects/stuod/hackathon/elnino/ ... done.
# ==> SIZE cci_sst_1981_2018.nc.gz ... 13170670
# ==> PASV ... done.    ==> RETR cci_sst_1981_2018.nc.gz ... done.
# Length: 13170670 (13M) (unauthoritative)
#
# cci_sst_1981_2018.n 100%[===================>]  12.56M   560KB/s    in 51s
#
# 2021-03-22 20:41:10 (252 KB/s) - Control connection closed.
# Retrying.
#
# --2021-03-22 20:41:11--  ftp://ftp.ifremer.fr/ifremer/cersat/projects/stuod/hackathon/elnino//cci_sst_1981_2018.nc.gz
#   (try: 2) => ‘cci_sst_1981_2018.nc.gz’
# ...

# %%
sst = xr.open_mfdataset('cci_sst_1981_2018.nc', combine='by_coords')

# %%
sst
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 90, lon: 180, time: 448)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-09-01 1981-10-01 ... 2018-12-01
#   * lon      (lon) float64 1.0 3.0 5.0 7.0 9.0 ... 351.0 353.0 355.0 357.0 359.0
#   * lat      (lat) float64 -89.0 -87.0 -85.0 -83.0 -81.0 ... 83.0 85.0 87.0 89.0
# Data variables:
#     sst      (lat, lon, time) float32 dask.array<chunksize=(90, 180, 448), meta=np.ndarray>
